# %% [markdown]
# # SSIM Autoencoderによる異常音検知

# %%
import numpy as np
import pandas as pd
import librosa as lb
import os
import re
import pathlib
import h5py
import joblib #並列処理のためのライブラリ
import shutil
from tqdm import tqdm # for文の進捗をプログレスバーで可視化する
import matplotlib.pyplot as plt
import glob
import wave
import tensorflow as tf

from audio_processing.librosa_compute_spectrogram import wav_to_spectrogram
from utils.data_loader import return_dataset_loader

from test import test
from utils import visualization
from utils import validate

# %% [markdown]
# ## MLflowのexperimentとRunを設定

# %% [markdown]
# ログが置かれたディレクトリを指定して以下のコマンドを実行(mlflowの環境下で実行)
#
# mlflow ui --backend-store-uri /path/to/uri --port 5000

# %%
import mlflow
from pathlib import Path

# フォルダが存在しない場合に作成
mlruns_folder = Path('./mlruns')
mlruns_folder.mkdir(parents=True, exist_ok=True)

# trackingの絶対パスを指定
TRACKING_URI = mlruns_folder.resolve()

EXPERIMENT_NAME ="SSIM Autoencoder"

# トラッキングサーバ（バックエンド）の場所を指定
mlflow.set_tracking_uri(TRACKING_URI)

# Experimentの生成
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
if experiment is None:  # 当該Experiment存在しないとき、新たに作成
    experiment_id = mlflow.create_experiment(
        name=EXPERIMENT_NAME
    )
else: # 当該Experiment存在するとき、IDを取得
    experiment_id = experiment.experiment_id


# Runを設定
RUN_NAME = 'SSIM Autoencoder'
TAGS={
    'version':'1',
}
description='Anomaly detection by ssim autoencoder'

# RUNを実行
with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME, tags=TAGS, description=description) as run:
    MLFLOW_RUN_ID = run.info.run_id
    
print("Experiment ID:", experiment_id)
print("Run ID:", MLFLOW_RUN_ID)
print("============================")

# ライフサイクルがdeletedになっているrunを削除（ストレージにrunが蓄積してしまうため）
relative_path = TRACKING_URI.relative_to(Path.cwd())
! mlflow gc --backend-store-uri $relative_path
# Out:
# Experiment ID: 0
# Run ID: 0c0473342a6a4f6587b16f0ae6097ed8
# ============================

# %%
# モジュールのオートリロード用のコマンド
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %% [markdown]
# 訓練データのパスを定義

# %%
'''
testdata : '210921_0032.wav' # 最終的な性能を評価するためのデータ
valdata : '210922_0033.wav' # 閾値などを検討する際に使用するデータ
'''
datas_dir = pathlib.Path('../../data/16000hz騒音データとスタートを合わせた音データ')
label_data_dir = pathlib.Path('../../data/学習データ(オリジナル)/')

all_traindata = [datas_dir/'210919_0031.wav', datas_dir/'210923_0034.wav', datas_dir/'210924_0035.wav']

print(all_traindata)
# Out:
# [WindowsPath('../../data/16000hz騒音データとスタートを合わせた音データ/210919_0031.wav'), WindowsPath('../../data/16000hz騒音データとスタートを合わせた音データ/210923_0034.wav'), WindowsPath('../../data/16000hz騒音データとスタートを合わせた音データ/210924_0035.wav')]

# %% [markdown]
# 各要素をラベルのDFとするリストを定義

# %%
# ラベルのDFを作成
list_df_labelData =[]
for i in all_traindata:
#     label_data_name = i.split('/')[-1].replace('.wav', '.csv') 
    labelData_name = i.with_suffix('.csv').name
    labelData_file = label_data_dir/labelData_name
    df_labelData=pd.read_csv(labelData_file, skiprows=4, usecols=[1], header=None) 
    list_df_labelData.append(df_labelData)

# display(list_df_labelData[0])

# %% [markdown]
# パラメータ

# %%
# スペクトログラムのパラメータ
SR = 16000 # サンプリング周波数
DURATION = 1 # スペクトログラムの時間幅[s]
# SPEC_PARAMS = {'frame_length':2048, 'frame_step':400} # スペクトログラムのパラメータ
MEL_PAEAMS = {'sr':SR, 'n_fft':2048, 'hop_length':512, 'n_mels':128, 'fmax':SR/2, 'fmin':80} # メル尺度のパラメータ
# npy関係のファイルを出力するフォルダ
NPY_OUTPUT = '../autoencoder-anomaly-detection/data_output/npy/train'

IMAGE_SIZE = [128, 32] # resizeする際のサイズ
VAL_RATE = 0.1  # 全データに対するバリデーションデータの割合
BATCH_SIZE = 2048 # バッチサイズ
EPOCHS = 100  # エポック数

# %% [markdown]
# 適用するデータ拡張を指定

# %%
transformName = [
    'GaussianNoiseSNR',
    'PinkNoiseSNR',
    'PitchShift',
    'TimeShift',
    'VolumeShift',
]

# %% [markdown]
# メルスペクトログラムに変換

# %%
# %%time
train_mean, train_std  = wav_to_spectrogram(NPY_OUTPUT,all_traindata, SR, DURATION, MEL_PAEAMS, transformName, list_df_labelData, 
                                            overwrite=False)
# Out:
# npy_output: ..\autoencoder-anomaly-detection\data_output\npy\train\npy_files
# ..\autoencoder-anomaly-detection\data_output\npy\trainが既に存在します
# 上書せずに終了
# Wall time: 3 ms

# %% [markdown]
# 標準化のための平均値と標準偏差を訓練データから算出。テストデータの標準化にも使用

# %%
print(f'平均値：{train_mean}')
print(f'標準偏差：{train_std}')
# Out:
# 平均値：-41.470706939697266
# 標準偏差：10.922344207763672

# %% [markdown]
# データセットの定義

# %%
# 訓練データを訓練データとバリデーションデータに分割
list_train_npyFiles = glob.glob(f'{NPY_OUTPUT}/npy_files/*')

# list_train_npyFiles = list_train_npyFiles[:10000]


num_all_data = len(list_train_npyFiles)
print('全データ数:', num_all_data)

index_array = np.array(range(num_all_data))
np.random.shuffle(index_array)
num_train_data = int(num_all_data*(1-VAL_RATE))
idx_train_data = index_array[:num_train_data]
idx_val_data = index_array[num_train_data:]
print('全データ×(1-VAL_RATE):', num_train_data)

train_npyFiles = [list_train_npyFiles[idx] for idx in idx_train_data]
val_npyFiles = [list_train_npyFiles[idx] for idx in idx_val_data]
print('訓練データ数：',len(train_npyFiles))
print('valデータ数：',len(val_npyFiles)) 

# データセット
train_dataset = return_dataset_loader(train_npyFiles,
                                      IMAGE_SIZE,
                                      mean=train_mean, 
                                      std=train_std, 
                                      training=True, 
                                      batch_size=BATCH_SIZE)
val_dataset = return_dataset_loader(val_npyFiles, 
                                    IMAGE_SIZE,
                                    mean=train_mean, 
                                    std=train_std, 
                                    training=True, 
                                    batch_size=BATCH_SIZE)
# Out:
# 全データ数: 170818
# 全データ×(1-VAL_RATE): 153736
# 訓練データ数： 153736
# valデータ数： 17082

# %%
####### mlflow ##########
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    mlflow.log_params(
        {
            "SR":SR,
            "DURATION":DURATION,
            "MEL_PAEAMS":MEL_PAEAMS,
            "IMAGE_SIZE":IMAGE_SIZE,
            "BATCH_SIZE":BATCH_SIZE,
            "EPOCHS":EPOCHS,
            "transformName":transformName,
            "train_mean":train_mean,
            "train_std":train_std,
            "Number of train data":num_all_data
        }
    )
#########################

# %% [markdown]
# # 訓練

# %%
# 実行時のスクリプトを保存
####### mlflow ##########
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    mlflow.log_artifact("Anomalydetection.ipynb", artifact_path="source_code")
    mlflow.log_artifact("./model/autoencoder.py", artifact_path="source_code/model")
########################

# %%
# モデルの定義
from model.autoencoder import AutoEncoder

# %% [markdown]
# ### SSIM Lossの定義

# %%
# ssim_loss
@tf.function
def ssim_loss(gt, y_pred, max_val=1.0):
    """
    gt:ground truth
    """
    return 1 - tf.reduce_mean(tf.image.ssim(gt, y_pred, max_val=max_val))

# %%
autoencoder = AutoEncoder(IMAGE_SIZE, 3)
autoencoder.compile(optimizer='adam', loss=ssim_loss, metrics=['mae'])
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 32, 3)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 32, 16)       448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 8, 8)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 8, 8)          584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 4, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 4, 8)          584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 8, 8)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 8, 8)          584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 16, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 16, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 32, 16)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 32, 3)        435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
# チェックポイント
dir_checkpoint = f'./data_output/tf_ckpts/{MLFLOW_RUN_ID}'
checkpoint_filepath =os.path.join(dir_checkpoint,  'best_val_loss.ckpt')
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# earlystopping 
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# %%
history = autoencoder.fit(train_dataset,  epochs=EPOCHS, validation_data=val_dataset, callbacks=[checkpoint, earlystopping])

pd.DataFrame({'loss':history.history['loss'], 'val_loss':history.history['val_loss']}).plot()
# Out:
# Epoch 1/100
# 76/76 [==============================] - 46s 438ms/step - loss: 0.5862 - mae: 0.1357 - val_loss: 0.4888 - val_mae: 0.0530
# Epoch 2/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.4787 - mae: 0.0488 - val_loss: 0.4613 - val_mae: 0.0434
# Epoch 3/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.4560 - mae: 0.0423 - val_loss: 0.4477 - val_mae: 0.0413
# Epoch 4/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.4451 - mae: 0.0412 - val_loss: 0.4411 - val_mae: 0.0417
# Epoch 5/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.4387 - mae: 0.0410 - val_loss: 0.4363 - val_mae: 0.0404
# Epoch 6/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.4343 - mae: 0.0404 - val_loss: 0.4329 - val_mae: 0.0407
# Epoch 7/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.4313 - mae: 0.0403 - val_loss: 0.4301 - val_mae: 0.0402
# Epoch 8/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.4289 - mae: 0.0397 - val_loss: 0.4280 - val_mae: 0.0397
# Epoch 9/100
# 76/76 [==============================] - 16s 186ms/step - loss: 0.4262 - mae: 0.0396 - val_loss: 0.4255 - val_mae: 0.0392
# Epoch 10/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.4240 - mae: 0.0394 - val_loss: 0.4236 - val_mae: 0.0414
# Epoch 11/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.4206 - mae: 0.0398 - val_loss: 0.4165 - val_mae: 0.0392
# Epoch 12/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.4142 - mae: 0.0394 - val_loss: 0.4119 - val_mae: 0.0389
# Epoch 13/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.4100 - mae: 0.0391 - val_loss: 0.4097 - val_mae: 0.0391
# Epoch 14/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.4073 - mae: 0.0393 - val_loss: 0.4043 - val_mae: 0.0384
# Epoch 15/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.4020 - mae: 0.0385 - val_loss: 0.4000 - val_mae: 0.0385
# Epoch 16/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3982 - mae: 0.0382 - val_loss: 0.3969 - val_mae: 0.0378
# Epoch 17/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3952 - mae: 0.0381 - val_loss: 0.3945 - val_mae: 0.0373
# Epoch 18/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3965 - mae: 0.0419 - val_loss: 0.3940 - val_mae: 0.0380
# Epoch 19/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3924 - mae: 0.0377 - val_loss: 0.3914 - val_mae: 0.0373
# Epoch 20/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3904 - mae: 0.0374 - val_loss: 0.3901 - val_mae: 0.0379
# Epoch 21/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3892 - mae: 0.0373 - val_loss: 0.3888 - val_mae: 0.0371
# Epoch 22/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3879 - mae: 0.0372 - val_loss: 0.3878 - val_mae: 0.0370
# Epoch 23/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3865 - mae: 0.0371 - val_loss: 0.3866 - val_mae: 0.0371
# Epoch 24/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3858 - mae: 0.0371 - val_loss: 0.3862 - val_mae: 0.0371
# Epoch 25/100
# 76/76 [==============================] - 16s 180ms/step - loss: 0.3848 - mae: 0.0370 - val_loss: 0.3846 - val_mae: 0.0370
# Epoch 26/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3834 - mae: 0.0370 - val_loss: 0.3847 - val_mae: 0.0365
# Epoch 27/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3831 - mae: 0.0371 - val_loss: 0.3829 - val_mae: 0.0370
# Epoch 28/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3817 - mae: 0.0369 - val_loss: 0.3818 - val_mae: 0.0370
# Epoch 29/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3809 - mae: 0.0369 - val_loss: 0.3810 - val_mae: 0.0365
# Epoch 30/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3800 - mae: 0.0369 - val_loss: 0.3799 - val_mae: 0.0367
# Epoch 31/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3790 - mae: 0.0368 - val_loss: 0.3793 - val_mae: 0.0365
# Epoch 32/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3782 - mae: 0.0368 - val_loss: 0.3781 - val_mae: 0.0366
# Epoch 33/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3771 - mae: 0.0367 - val_loss: 0.3773 - val_mae: 0.0364
# Epoch 34/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3765 - mae: 0.0367 - val_loss: 0.3763 - val_mae: 0.0365
# Epoch 35/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3756 - mae: 0.0366 - val_loss: 0.3755 - val_mae: 0.0363
# Epoch 36/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3750 - mae: 0.0366 - val_loss: 0.3749 - val_mae: 0.0365
# Epoch 37/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3743 - mae: 0.0367 - val_loss: 0.3744 - val_mae: 0.0359
# Epoch 38/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3736 - mae: 0.0367 - val_loss: 0.3737 - val_mae: 0.0371
# Epoch 39/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3726 - mae: 0.0365 - val_loss: 0.3730 - val_mae: 0.0363
# Epoch 40/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3718 - mae: 0.0366 - val_loss: 0.3724 - val_mae: 0.0360
# Epoch 41/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3714 - mae: 0.0364 - val_loss: 0.3719 - val_mae: 0.0357
# Epoch 42/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3704 - mae: 0.0365 - val_loss: 0.3707 - val_mae: 0.0359
# Epoch 43/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3697 - mae: 0.0362 - val_loss: 0.3709 - val_mae: 0.0382
# Epoch 44/100
# 76/76 [==============================] - 16s 180ms/step - loss: 0.3693 - mae: 0.0364 - val_loss: 0.3692 - val_mae: 0.0358
# Epoch 45/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3685 - mae: 0.0362 - val_loss: 0.3690 - val_mae: 0.0362
# Epoch 46/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3680 - mae: 0.0361 - val_loss: 0.3682 - val_mae: 0.0365
# Epoch 47/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3676 - mae: 0.0363 - val_loss: 0.3675 - val_mae: 0.0360
# Epoch 48/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3669 - mae: 0.0362 - val_loss: 0.3669 - val_mae: 0.0365
# Epoch 49/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3664 - mae: 0.0364 - val_loss: 0.3663 - val_mae: 0.0361
# Epoch 50/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3657 - mae: 0.0360 - val_loss: 0.3662 - val_mae: 0.0354
# Epoch 51/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3651 - mae: 0.0360 - val_loss: 0.3653 - val_mae: 0.0354
# Epoch 52/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3642 - mae: 0.0359 - val_loss: 0.3647 - val_mae: 0.0355
# Epoch 53/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3642 - mae: 0.0360 - val_loss: 0.3644 - val_mae: 0.0366
# Epoch 54/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3634 - mae: 0.0360 - val_loss: 0.3638 - val_mae: 0.0356
# Epoch 55/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3633 - mae: 0.0360 - val_loss: 0.3634 - val_mae: 0.0359
# Epoch 56/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3630 - mae: 0.0359 - val_loss: 0.3630 - val_mae: 0.0359
# Epoch 57/100
# 76/76 [==============================] - 16s 186ms/step - loss: 0.3625 - mae: 0.0358 - val_loss: 0.3626 - val_mae: 0.0355
# Epoch 58/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3619 - mae: 0.0358 - val_loss: 0.3624 - val_mae: 0.0352
# Epoch 59/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3616 - mae: 0.0361 - val_loss: 0.3628 - val_mae: 0.0396
# Epoch 60/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3615 - mae: 0.0363 - val_loss: 0.3617 - val_mae: 0.0361
# Epoch 61/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3611 - mae: 0.0357 - val_loss: 0.3616 - val_mae: 0.0356
# Epoch 62/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3608 - mae: 0.0357 - val_loss: 0.3611 - val_mae: 0.0362
# Epoch 63/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3606 - mae: 0.0358 - val_loss: 0.3609 - val_mae: 0.0361
# Epoch 64/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3602 - mae: 0.0358 - val_loss: 0.3605 - val_mae: 0.0361
# Epoch 65/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3597 - mae: 0.0357 - val_loss: 0.3607 - val_mae: 0.0355
# Epoch 66/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3601 - mae: 0.0362 - val_loss: 0.3600 - val_mae: 0.0354
# Epoch 67/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3594 - mae: 0.0358 - val_loss: 0.3598 - val_mae: 0.0354
# Epoch 68/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3594 - mae: 0.0358 - val_loss: 0.3595 - val_mae: 0.0355
# Epoch 69/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3590 - mae: 0.0357 - val_loss: 0.3594 - val_mae: 0.0352
# Epoch 70/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3586 - mae: 0.0357 - val_loss: 0.3595 - val_mae: 0.0356
# Epoch 71/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3582 - mae: 0.0358 - val_loss: 0.3599 - val_mae: 0.0360
# Epoch 72/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3582 - mae: 0.0358 - val_loss: 0.3588 - val_mae: 0.0356
# Epoch 73/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3581 - mae: 0.0357 - val_loss: 0.3595 - val_mae: 0.0358
# Epoch 74/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3580 - mae: 0.0359 - val_loss: 0.3585 - val_mae: 0.0357
# Epoch 75/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3575 - mae: 0.0357 - val_loss: 0.3584 - val_mae: 0.0360
# Epoch 76/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3574 - mae: 0.0357 - val_loss: 0.3597 - val_mae: 0.0350
# Epoch 77/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3578 - mae: 0.0357 - val_loss: 0.3578 - val_mae: 0.0354
# Epoch 78/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3576 - mae: 0.0358 - val_loss: 0.3580 - val_mae: 0.0365
# Epoch 79/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3567 - mae: 0.0359 - val_loss: 0.3576 - val_mae: 0.0354
# Epoch 80/100
# 76/76 [==============================] - 16s 181ms/step - loss: 0.3568 - mae: 0.0357 - val_loss: 0.3574 - val_mae: 0.0353
# Epoch 81/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3568 - mae: 0.0359 - val_loss: 0.3588 - val_mae: 0.0394
# Epoch 82/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3567 - mae: 0.0359 - val_loss: 0.3585 - val_mae: 0.0364
# Epoch 83/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3565 - mae: 0.0358 - val_loss: 0.3569 - val_mae: 0.0353
# Epoch 84/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3560 - mae: 0.0358 - val_loss: 0.3569 - val_mae: 0.0352
# Epoch 85/100
# 76/76 [==============================] - 16s 187ms/step - loss: 0.3560 - mae: 0.0356 - val_loss: 0.3568 - val_mae: 0.0364
# Epoch 86/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3562 - mae: 0.0357 - val_loss: 0.3565 - val_mae: 0.0355
# Epoch 87/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3556 - mae: 0.0358 - val_loss: 0.3565 - val_mae: 0.0361
# Epoch 88/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3558 - mae: 0.0360 - val_loss: 0.3564 - val_mae: 0.0354
# Epoch 89/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3555 - mae: 0.0356 - val_loss: 0.3561 - val_mae: 0.0358
# Epoch 90/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3556 - mae: 0.0358 - val_loss: 0.3561 - val_mae: 0.0351
# Epoch 91/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3552 - mae: 0.0358 - val_loss: 0.3556 - val_mae: 0.0354
# Epoch 92/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3550 - mae: 0.0357 - val_loss: 0.3565 - val_mae: 0.0358
# Epoch 93/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3548 - mae: 0.0360 - val_loss: 0.3558 - val_mae: 0.0353
# Epoch 94/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3550 - mae: 0.0357 - val_loss: 0.3564 - val_mae: 0.0387
# Epoch 95/100
# 76/76 [==============================] - 16s 186ms/step - loss: 0.3549 - mae: 0.0361 - val_loss: 0.3556 - val_mae: 0.0354
# Epoch 96/100
# 76/76 [==============================] - 16s 185ms/step - loss: 0.3545 - mae: 0.0358 - val_loss: 0.3559 - val_mae: 0.0373
# Epoch 97/100
# 76/76 [==============================] - 16s 184ms/step - loss: 0.3543 - mae: 0.0357 - val_loss: 0.3555 - val_mae: 0.0350
# Epoch 98/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3544 - mae: 0.0357 - val_loss: 0.3549 - val_mae: 0.0353
# Epoch 99/100
# 76/76 [==============================] - 16s 182ms/step - loss: 0.3542 - mae: 0.0358 - val_loss: 0.3549 - val_mae: 0.0353
# Epoch 100/100
# 76/76 [==============================] - 16s 183ms/step - loss: 0.3541 - mae: 0.0359 - val_loss: 0.3549 - val_mae: 0.0354
# <AxesSubplot:>

# %%
######## MLflow ########################
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    # チェックポイントを保存
    mlflow.log_artifacts(dir_checkpoint, artifact_path="checkpoint")
    
    # historyを保存
    for epoch in range(EPOCHS):
        mlflow.log_metric(
            "loss", history.history["loss"][epoch], step=epoch
        )
        mlflow.log_metric(
            "val_loss", history.history["val_loss"][epoch], step=epoch
        )
        mlflow.log_metric(
            "mae", history.history["mae"][epoch], step=epoch
        )
        mlflow.log_metric(
            "val_mae",history.history["val_mae"][epoch], step=epoch,
        )

# %% [markdown]
# # 推論フェーズ

# %%
'''
testdata : '210921_0032.wav' # 最終的な性能を評価するためのデータ
valdata : '210922_0033.wav' # 閾値などを検討する際に使用するデータ
'''
# テストデータ
testdata = '210921_0032'
testdata_path = [datas_dir/(testdata+'.wav')]
path_label_data = pathlib.Path('../../data/学習データ(ラベル修正)/-2109220600/-2109220600.csv')
df_test_label=pd.read_csv(path_label_data, skiprows=4, usecols=[1], header=None)  # fileをデータフレームに出力

display(df_test_label)

# 0.2秒単位のラベルをduration単位の配列に変換する
array_testlabel_data = df_test_label.iloc[:, 0].values # dfを一次元配列に変換
label_unit = validate.convert_label_unit(array_testlabel_data, duration=DURATION, list_anomalyLabel=[1, 2])
# Out:
#         1
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...    ..
# 287480  0
# 287481  0
# 287482  0
# 287483  0
# 287484  0
#
# [287485 rows x 1 columns]

# %% [markdown]
# テストデータをメルスペクトログラムに変換

# %%
# テストデータのnpyファイルの出力先
TEST_NPY_OUTPUT = f'./data_output/npy/test/{testdata}'
# テストするモデルのパス
MODEL_PATH = ''

# %%
# %%time
_, _ = wav_to_spectrogram(TEST_NPY_OUTPUT, testdata_path, SR, DURATION, MEL_PAEAMS, overwrite=True)
# Out:
# npy_output: data_output\npy\test\210921_0032\npy_files
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 76.92it/s]
# Wall time: 4min 44s

# %% [markdown]
# テストデータのデータセット作成

# %%
# npyファイルのリストを時系列順にする必要がある
def extract_number(path):
    """
    ファイル名に付与されている番号でソートするための関数
    """
    filename = pathlib.Path(path).name
    match = re.search(r'(\d+)(_.*)', filename)
    try:
        key = int(match.group(1))
        return key
    
    except Exception as e:
        print(e)

list_test_npyFiles = glob.glob(f'{TEST_NPY_OUTPUT}/npy_files/*')
list_test_npyFiles.sort(key=extract_number)  # ファイル名に付与された数字でリストをソート
# print(list_test_npyFiles)

# %%
num_all_test_data = len(list_test_npyFiles)
print('全データ数:', num_all_test_data)

# データセット
test_dataset = return_dataset_loader(list_test_npyFiles,
                                      IMAGE_SIZE,
                                      training=False, 
                                      mean=train_mean, 
                                      std=train_std, 
                                      batch_size=BATCH_SIZE)

# for i in test_dataset:
#     print(tf.shape(i))
#     print(i)
# Out:
# 全データ数: 57496

# %% [markdown]
# ### 最良モデルの読み込み

# %%
# 重みの読み込み
autoencoder = AutoEncoder(IMAGE_SIZE, 3)
autoencoder.load_weights(checkpoint_filepath)
autoencoder.compile(optimizer='adam', loss=ssim_loss, metrics=['mae'])
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 32, 3)]      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 32, 16)       448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 16, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 8, 8)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 8, 8)          584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 4, 8)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 4, 8)          584
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 8, 8)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 8, 8)          584
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 16, 8)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 16, 16)        1168
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 128, 32, 16)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 32, 3)        435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 異常度算出

# %%
# %%time
anomaly_score = test(autoencoder, test_dataset)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:46<00:00,  1.59s/it]
# Wall time: 46 s

# %% [markdown]
# ### 閾値の計算
#
# 訓練データに対する異常度の平均よりS×標準偏差上の値を閾値とする

# %%
# 閾値の計算
S = 0.5
train_anomaly_score = test(autoencoder, train_dataset)
THRESHOLD = np.mean(train_anomaly_score) + S*np.std(train_anomaly_score)
print("Threshold: ", THRESHOLD)

plt.hist(anomaly_score, bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 76/76 [00:12<00:00,  5.95it/s]
# Threshold:  0.038685775334783644

# %% [markdown]
# ## 評価

# %%
auPR, fig, thr_max_f_score, _  = validate.plot_PR(label_unit, anomaly_score, 100)
fig_PR = validate.plot_to_image(fig)
print(f"AU PR:{auPR}")
# Out:
# AU PR:0.6711036147442425

# %%
auROC, fig = validate.plot_ROC(label_unit, anomaly_score, 100)
fig_ROC = validate.plot_to_image(fig)
print(f"AU ROC:{auROC}")
# Out:
# AU ROC:0.9815931953495913

# %%
####### mlflow ##########
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    mlflow.log_metric("Threshold", THRESHOLD)
    
    mlflow.log_metric("AU PR", auPR)
    mlflow.log_metric("AU ROC", auROC)

    mlflow.log_image(fig_PR.numpy()[0], 'fig_PR.png')
    mlflow.log_image(fig_ROC.numpy()[0], 'fig_ROC.png')
########################

# %% [markdown]
# ## 異常度可視化

# %%
start='2022-09-21 06:00:00'
end='2022-09-21 22:00:00'

uLimit=anomaly_score.max()

fig = visualization.plot_anomaly_score(start, end, DURATION, anomaly_score, label_unit, thr_max_f_score, uLimit)
fig_anomalyscore = visualization.plot_to_image(fig)

####### mlflow ##########
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    mlflow.log_image(fig_anomalyscore.numpy()[0], 'fig_anomalyscore.png')
########################

# %% [markdown]
# ## 異常データの再構成画像可視化

# %%
def plot_spectrogram(x):
    fig, axes = plt.subplots(1, figsize=(12, 8))
    axes.imshow(x, origin='lower')
    axes.set_title('Spectrogram')
    
    return fig

# %%
# %%time
import tensorflow as tf

abnormal_wav = ["../../data/閾値に使用するデータ/wav_異常音/210922_0033/210922_0033_0;0;11-0;0;13.wav"]
abnormal_npy = "./data_output/npy/abnormal"

_, _ = wav_to_spectrogram(abnormal_npy, abnormal_wav, SR, DURATION, MEL_PAEAMS, overwrite=True)

list_abnormal_npyFiles = glob.glob(f'{abnormal_npy}/npy_files/*')
# データセット
abnormal_dataset = return_dataset_loader(list_abnormal_npyFiles,
                                      IMAGE_SIZE,
                                      training=False, 
                                      mean=train_mean, 
                                      std=train_std, 
                                      batch_size=BATCH_SIZE)

for batch_x, batch_y in abnormal_dataset.take(1):
    input_image = batch_x[0]
    fig = plot_spectrogram(input_image)
    image_input = visualization.plot_to_image(fig)

    batch_image = tf.expand_dims(input_image,axis=0)
    model_x = autoencoder.predict(batch_image)
    fig = plot_spectrogram(model_x[0])
    image_output = visualization.plot_to_image(fig)
    
####### mlflow ##########
with mlflow.start_run(run_id=MLFLOW_RUN_ID):
    mlflow.log_image(image_input.numpy()[0], 'image_input.png')
    mlflow.log_image(image_output.numpy()[0], 'image_output.png')
########################
# Out:
# npy_output: data_output\npy\abnormal\npy_files
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 988.52it/s]
# Wall time: 4.48 s
